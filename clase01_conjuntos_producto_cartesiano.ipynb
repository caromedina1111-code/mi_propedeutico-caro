# %% [markdown]
# # **Clase 1 · Python y Google Colab desde cero**
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1OsViyvhidE9EU6CsUL2uw4LLjuD4CzhF?usp=sharing)
#
# **Profesor:** Francisco Pérez

# %% [markdown]
# ## **Conjuntos y producto cartesiano**
#
# **Propedéutico de Matemáticas y Programación · FLACSO Ecuador**
#
# *No requiere instalar nada: solo un navegador y una cuenta de Google.*
#
# ---
#
# **Objetivos.** Al finalizar la clase podrás:
#
# 1. Usar Google Colab: crear, editar y ejecutar celdas de texto y de código.
# 2. Ejecutar tus primeras instrucciones en Python: variables, operaciones aritméticas y `print()`.
# 3. Definir conjuntos en Python y operar con ellos: unión, intersección, diferencia, diferencia simétrica y contención.
# 4. Construir el producto cartesiano $A \times B$ y verificar la regla del producto $|A \times B| = |A| \cdot |B|$.
#
# **Metodología — «Yo hago / Tú haces».** Cada tema tiene dos momentos: primero el/la docente ejecuta y explica (🧑‍🏫 **Yo hago**); luego tú resuelves un ejercicio análogo (✍️ **Tú haces**). Cada ejercicio trae una solución oculta: haz un intento honesto **antes** de mirarla.

# %% [markdown]
# ## 1. Bienvenida a Google Colab
#
# Google Colab es un **cuaderno interactivo en la nube**: combina texto explicativo (como este) con código Python que se ejecuta en servidores de Google, sin instalar nada en tu computadora.
#
# **Lo esencial en cinco puntos:**
#
# 1. **Guarda tu copia.** Ve a `Archivo → Guardar una copia en Drive`. Trabajarás sobre tu propia versión y tus cambios quedarán en tu Google Drive.
# 2. **Hay dos tipos de celda.** Celdas de *texto* (explicaciones, como esta) y celdas de *código* (fondo gris, ejecutables).
# 3. **Ejecutar una celda.** Haz clic sobre ella y presiona `Ctrl + Enter` (o `Shift + Enter` para ejecutar y saltar a la siguiente). También funciona el botón ▶ que aparece a la izquierda de la celda.
# 4. **Crear celdas.** Usa los botones `+ Código` y `+ Texto` de la barra superior.
# 5. **La primera ejecución tarda unos segundos.** Colab debe *conectarse* a una máquina virtual (verás «Conectando…» arriba a la derecha). Es normal.
#
# > 💡 **Nada se rompe de forma permanente.** Si algo sale mal, `Entorno de ejecución → Reiniciar entorno de ejecución` reinicia Python y puedes volver a ejecutar todo desde el inicio. Y si ves un mensaje en rojo, no es un castigo: es un **mensaje de error** que describe qué falló; la pista más útil suele estar en la **última línea**.

# %% [markdown]
# ### 🧑‍🏫 Yo hago 1.1 — Mi primera celda de código
#
# Ejecuta la celda siguiente (clic sobre ella y `Ctrl + Enter`). La función `print()` muestra en pantalla lo que pongas entre paréntesis.

# %%
print("¡Hola, FLACSO! Esta es mi primera celda de código.")
# Out:
# ¡Hola, FLACSO! Esta es mi primera celda de código.

# %% [markdown]
# ### ✍️ Tú haces 1.1
#
# Crea una **celda de código nueva** debajo de esta (botón `+ Código`) y usa `print()` para mostrar tu nombre y el programa que cursas.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# print("Me llamo Ana y curso la Maestría en Economía del Desarrollo.")
# ```
#
# **Comentario:** el texto va entre comillas (dobles o simples, pero cerradas). Olvidar una comilla es el error más común del primer día.
#
# </details>

# %%
print("Hola mi nombre es Carolina soy Economista")
# Out:
# Hola mi nombre es Carolina soy Economista

# %% [markdown]
# ## 2. Python en diez minutos: operaciones y variables
#
# Antes de los conjuntos necesitamos tres ideas mínimas:
#
# 1. **Python es una calculadora:** `+`, `-`, `*`, `/` y `**` (potencia).
# 2. **Una variable es un nombre que guarda un valor.** El símbolo `=` significa *asignación* («guarda esto con este nombre»), no igualdad matemática.
# 3. **Los comentarios empiezan con `#`.** Python los ignora: son notas para humanos.

# %% [markdown]
# ### 🧑‍🏫 Yo hago 2.1 — Calculadora y variables

# %%
# Python como calculadora
print(7 + 5)     # suma
print(7 * 5)     # multiplicación
print(7 / 5)     # división (siempre devuelve decimal)
print(7 ** 2)    # potencia: 7 al cuadrado

# Variables: nombres que guardan valores
matriculados = 25
aprobados = 21
tasa_aprobacion = aprobados / matriculados

print("Tasa de aprobación:", tasa_aprobacion)
print(f"Número de matriculados: {matriculados}")
# Out:
# 12
# 35
# 1.4
# 49
# Tasa de aprobación: 0.84
# Número de matriculados: 25

# %% [markdown]
# ### ✍️ Tú haces 2.1
#
# Con cifras redondeadas con fines didácticos, supongamos que el PIB de Ecuador es de **120 mil millones de dólares** y su población es de **18 millones de personas**. Define dos variables (`pib` y `poblacion`), calcula el PIB per cápita en una tercera variable y muéstralo con `print()`.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# pib = 120_000_000_000      # el guion bajo separa miles y Python lo ignora
# poblacion = 18_000_000
#
# pib_per_capita = pib / poblacion
# print("PIB per cápita (USD):", pib_per_capita)
# ```
#
# **Comentario:** debe darte `6666.66…` dólares. Observa que los nombres de variables no llevan tildes ni espacios: usamos `poblacion`, no `población`.
#
# </details>

# %%
#pib_per_capita
pib = 120_000_000_000
poblacion = 18_000_000  
pib_per_capita = pib / poblacion
print("pib_per_cápita:", pib_per_capita)
# Out:
# pib_per_cápita: 6666.666666666667

# %% [markdown]
# ## 3. Conjuntos: de la pizarra a Python
#
# En matemáticas, un **conjunto** es una colección **no ordenada** de elementos **distintos**:
#
# $$A = \{1, 2, 3, 4\}$$
#
# Decimos que $2 \in A$ («2 pertenece a $A$»), que $7 \notin A$, y llamamos **cardinalidad** $|A|$ al número de elementos.
#
# En Python la traducción es casi literal:
#
# | Matemáticas | Python | Se lee |
# |---|---|---|
# | $A = \{1, 2, 3\}$ | `A = {1, 2, 3}` | el conjunto $A$ |
# | $2 \in A$ | `2 in A` | 2 pertenece a $A$ |
# | $7 \notin A$ | `7 not in A` | 7 no pertenece a $A$ |
# | $\lvert A \rvert$ | `len(A)` | cardinalidad de $A$ |
# | $\emptyset$ | `set()` | conjunto vacío |
#
# > ⚠️ **Trampa clásica:** `{}` **no** crea un conjunto vacío sino un *diccionario* (otra estructura que veremos más adelante). El conjunto vacío se escribe `set()`.

# %% [markdown]
# ### 🧑‍🏫 Yo hago 3.1 — Definir un conjunto, pertenencia y cardinalidad

# %%
# Un conjunto se define con llaves
A = {1, 2, 3, 4}
print("A =", A)
print("Cardinalidad |A| =", len(A))

# Pertenencia: el operador 'in' devuelve True (verdadero) o False (falso)
print("¿2 ∈ A?", 2 in A)
print("¿7 ∈ A?", 7 in A)
print("¿7 ∉ A?", 7 not in A)
# Out:
# A = {1, 2, 3, 4}
# Cardinalidad |A| = 4
# ¿2 ∈ A? True
# ¿7 ∈ A? False
# ¿7 ∉ A? True

# %% [markdown]
# ### 🧑‍🏫 Yo hago 3.2 — Dos propiedades que Python respeta solo
#
# Los conjuntos **eliminan duplicados automáticamente** y **no tienen orden**. Ambas propiedades son matemáticas, no caprichos del lenguaje: $\{1, 2, 2\} = \{1, 2\}$ y $\{1, 2\} = \{2, 1\}$.

# %%
# Propiedad 1: los duplicados se eliminan solos
votos = {"Ana", "Luis", "Ana", "María", "Luis"}
print("Personas distintas que votaron:", votos)
print("Número de votantes:", len(votos))

# Propiedad 2: un conjunto NO tiene orden interno.
# El orden en que se imprime puede variar entre sesiones; si necesitas
# una presentación ordenada, usa sorted(), que devuelve una lista ordenada.
print("Presentación ordenada:", sorted(votos))

# El conjunto vacío se crea con set(), no con {}
vacio = set()
print("Conjunto vacío:", vacio, "| cardinalidad:", len(vacio))
# Out:
# Personas distintas que votaron: {'Luis', 'Ana', 'María'}
# Número de votantes: 3
# Presentación ordenada: ['Ana', 'Luis', 'María']
# Conjunto vacío: set() | cardinalidad: 0

# %% [markdown]
# ### ✍️ Tú haces 3.1
#
# Crea un conjunto `paises_visitados` con al menos cuatro países, **repitiendo uno a propósito**. Luego: (a) imprime el conjunto, (b) imprime su cardinalidad, y (c) verifica con `in` si `"Ecuador"` pertenece.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# paises_visitados = {"Ecuador", "Perú", "Colombia", "Chile", "Perú"}
#
# print("Conjunto:", paises_visitados)
# print("Cardinalidad:", len(paises_visitados))          # 4, no 5: "Perú" se cuenta una vez
# print("¿Ecuador pertenece?", "Ecuador" in paises_visitados)
# ```
#
# **Comentario:** aunque escribiste cinco elementos, la cardinalidad es 4 porque el duplicado desaparece. Esa es exactamente la definición matemática de conjunto.
#
# </details>

# %%
# Propiedad 1: Los duplicados se eliminan solos 
paises_visitados = {"Argentina", "Brasil", "Republica", "Argentina", "Uruguay","Colombia", "Brasil"}
print("paises visitados:", paises_visitados)
print("Número de paises visitados:", len(paises_visitados))
# Out:
# paises visitados: {'Republica', 'Uruguay', 'Argentina', 'Colombia', 'Brasil'}
# Número de paises visitados: 5

# %% [markdown]
# ## 4. Operaciones entre conjuntos
#
# Las cuatro operaciones básicas y la relación de contención, con su traducción a Python:
#
# | Operación | Definición | Python |
# |---|---|---|
# | Unión | $A \cup B = \{x : x \in A \ \text{o} \ x \in B\}$ | `A \| B` |
# | Intersección | $A \cap B = \{x : x \in A \ \text{y} \ x \in B\}$ | `A & B` |
# | Diferencia | $A \setminus B = \{x : x \in A \ \text{y} \ x \notin B\}$ | `A - B` |
# | Diferencia simétrica | $A \triangle B = (A \setminus B) \cup (B \setminus A)$ | `A ^ B` |
# | Subconjunto | $A \subseteq B$ | `A <= B` |
#
# > 💡 También existen los métodos equivalentes `A.union(B)`, `A.intersection(B)`, `A.difference(B)`, `A.symmetric_difference(B)` y `A.issubset(B)`. Usaremos los operadores porque se parecen más a la notación matemática.

# %% [markdown]
# ### 🧑‍🏫 Yo hago 4.1 — Las cuatro operaciones con números

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7}
 
print("A ∪ B =", A | B)     # unión: elementos en A o en B (o en ambos)
print("A ∩ B =", A & B)     # intersección: elementos en A y en B a la vez
print("A \\ B =", A - B)     # diferencia: en A pero no en B
print("B \\ A =", B - A)     # ¡la diferencia NO es conmutativa!
print("A △ B =", A ^ B)     # diferencia simétrica: en uno u otro, pero no en ambos
 
# Contención
print("¿{1, 2} ⊆ A?", {1, 2} <= A)
print("¿A ⊆ B?", A <= B)
# Out:
# A ∪ B = {1, 2, 3, 4, 5, 6, 7}
# A ∩ B = {4, 5}
# A \ B = {1, 2, 3}
# B \ A = {6, 7}
# A △ B = {1, 2, 3, 6, 7}
# ¿{1, 2} ⊆ A? True
# ¿A ⊆ B? False

# %% [markdown]
# ### 🧑‍🏫 Yo hago 4.2 — Ejemplo aplicado: geografía política de Sudamérica
#
# Sea el conjunto de países **andinos** (atravesados por la cordillera) y el de países **amazónicos** (miembros de la OTCA, la Organización del Tratado de Cooperación Amazónica). Las operaciones de conjuntos responden preguntas sustantivas de forma inmediata.

# %%
andinos = {"Venezuela", "Colombia", "Ecuador", "Perú", "Bolivia", "Chile", "Argentina"}
amazonicos = {"Brasil", "Bolivia", "Colombia", "Ecuador", "Guyana", "Perú", "Surinam", "Venezuela"}

print("Andinos y amazónicos a la vez:", sorted(andinos & amazonicos))
print("Andinos que no son amazónicos:", sorted(andinos - amazonicos))
print("Amazónicos que no son andinos:", sorted(amazonicos - andinos))
print("Total de países mencionados:", len(andinos | amazonicos))
# Out:
# Andinos y amazónicos a la vez: ['Bolivia', 'Colombia', 'Ecuador', 'Perú', 'Venezuela']
# Andinos que no son amazónicos: ['Argentina', 'Chile']
# Amazónicos que no son andinos: ['Brasil', 'Guyana', 'Surinam']
# Total de países mencionados: 10

# %% [markdown]
# ### ✍️ Tú haces 4.1 — Primero a mano, luego en Python
#
# Sean $A = \{2, 4, 6, 8\}$ y $B = \{1, 2, 3, 4\}$. **En papel**, calcula $A \cup B$, $A \cap B$, $A \setminus B$, $B \setminus A$ y $A \triangle B$. Después verifica tus respuestas en la celda de código.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# A = {2, 4, 6, 8}
# B = {1, 2, 3, 4}
#
# print("A ∪ B =", A | B)   # {1, 2, 3, 4, 6, 8}
# print("A ∩ B =", A & B)   # {2, 4}
# print("A \\ B =", A - B)   # {6, 8}
# print("B \\ A =", B - A)   # {1, 3}
# print("A △ B =", A ^ B)   # {1, 3, 6, 8}
# ```
#
# **Comentario:** verifica una identidad útil: $A \triangle B = (A \cup B) \setminus (A \cap B)$. En Python: `(A | B) - (A & B)` debe dar el mismo resultado que `A ^ B`.
#
# </details>

# %%
# ✍️ Escribe aquí tu solución del Tú haces 4.1
A = {2, 4, 6, 8}
B = {1, 2, 3, 4} 
print("A ∪ B =", A | B)     # unión: elementos en A o en B (o en ambos)
print("A ∩ B =", A & B)     # intersección: elementos en    
print("A \\ B =", A - B)     # diferencia: en A pero no en B
print("B \\ A =", B - A)     # ¡la diferencia NO es conmutativa!
print("A △ B =", A ^ B)     # diferencia simétrica: en uno
# Out:
# A ∪ B = {1, 2, 3, 4, 6, 8}
# A ∩ B = {2, 4}
# A \ B = {8, 6}
# B \ A = {1, 3}
# A △ B = {1, 3, 6, 8}

# %% [markdown]
# ### ✍️ Tú haces 4.2 — Aplicación: aprobación de cursos
#
# En el propedéutico, el conjunto `M` reúne a quienes aprobaron *Matemáticas* y `E` a quienes aprobaron *Estadística*:
#
# ```python
# M = {"Ana", "Luis", "María", "Pedro", "Sofía"}
# E = {"Luis", "Carmen", "Sofía", "Jorge"}
# ```
#
# Responde con operaciones de conjuntos: (a) ¿quiénes aprobaron **ambos** cursos?, (b) ¿quiénes aprobaron **solo** Matemáticas?, (c) ¿cuántas personas aprobaron **al menos uno**?, (d) ¿quiénes aprobaron **exactamente uno**?
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# M = {"Ana", "Luis", "María", "Pedro", "Sofía"}
# E = {"Luis", "Carmen", "Sofía", "Jorge"}
#
# print("(a) Ambos:", M & E)                    # {"Luis", "Sofía"}
# print("(b) Solo Matemáticas:", M - E)         # {"Ana", "María", "Pedro"}
# print("(c) Al menos uno:", len(M | E))        # 7 personas
# print("(d) Exactamente uno:", M ^ E)          # {"Ana", "María", "Pedro", "Carmen", "Jorge"}
# ```
#
# **Comentario:** nota la correspondencia lenguaje–operación: *ambos* → intersección, *solo* → diferencia, *al menos uno* → unión, *exactamente uno* → diferencia simétrica. Traducir preguntas verbales a operaciones es la destreza central de esta sección.
#
# </details>

# %%
# ✍️ Escribe aquí tu solución del Tú haces 4.2
M = {"Ana", "Luis", "María", "Pedro", "Sofía"}
E = {"Luis", "Carmen", "Sofía", "Jorge"}
print("M&E =", M & E)     # intersección: elementos en M y en E a la vez
print("M ∪ E =", M | E)     # unión: elementos en M o en E (o en ambos)
print("M-E =", M - E)       # diferencia: en M pero no en E
print("M ^ E =", M ^ E)       # diferencia simétrica: en uno u otro, pero no en ambos
# Out:
# M&E = {'Luis', 'Sofía'}
# M ∪ E = {'Luis', 'María', 'Ana', 'Carmen', 'Sofía', 'Pedro', 'Jorge'}
# M-E = {'María', 'Ana', 'Pedro'}
# M ^ E = {'María', 'Ana', 'Carmen', 'Pedro', 'Jorge'}

# %% [markdown]
# ## 5. Producto cartesiano
#
# El **producto cartesiano** de $A$ y $B$ es el conjunto de todos los **pares ordenados** cuya primera componente está en $A$ y la segunda en $B$:
#
# $$A \times B = \{(a, b) : a \in A \ \text{y} \ b \in B\}$$
#
# Dos ideas clave:
#
# - En un **par ordenado el orden importa**: $(1, 2) \neq (2, 1)$. En Python, un par ordenado es una **tupla**: `(a, b)`.
# - **Regla del producto:** $|A \times B| = |A| \cdot |B|$. Este principio de conteo es la base de los diseños muestrales y experimentales que verás en estadística.
#
# El nombre no es casual: el **plano cartesiano** de Descartes es exactamente $\mathbb{R} \times \mathbb{R} = \mathbb{R}^2$, el conjunto de todos los pares ordenados de números reales.

# %% [markdown]
# ### 🧑‍🏫 Yo hago 5.1 — Tuplas: donde el orden sí importa

# %%
# Una tupla es una pareja (o n-tupla) ORDENADA; se escribe con paréntesis
par1 = (1, 2)
par2 = (2, 1)

print("par1 =", par1)
print("par2 =", par2)
print("¿(1, 2) == (2, 1)?", par1 == par2)      # False: en las tuplas el orden importa

# Compara con los conjuntos, donde el orden NO importa
print("¿{1, 2} == {2, 1}?", {1, 2} == {2, 1})  # True
# Out:
# par1 = (1, 2)
# par2 = (2, 1)
# ¿(1, 2) == (2, 1)? False
# ¿{1, 2} == {2, 1}? True

# %% [markdown]
# ### 🧑‍🏫 Yo hago 5.2 — Construir $A \times B$ por comprensión
#
# Python permite escribir conjuntos **por comprensión**, calcando la notación matemática. Compara:
#
# $$A \times B = \{(a, b) : a \in A, \ b \in B\}$$
#
# ```python
# AxB = {(a, b) for a in A for b in B}
# ```
#
# Se lee igual: «el conjunto de las parejas $(a, b)$, para cada $a$ en $A$ y cada $b$ en $B$».

# %%
A = {1, 2, 3}
B = {"do", "re"}


# Producto cartesiano por comprensión
AxB = {(a, b) for a in A for b in B}

print("A × B =", sorted(AxB))
print("|A| =", len(A), " |B| =", len(B), " |A × B| =", len(AxB))
print("¿Se cumple |A × B| == |A| · |B|?", len(AxB) == len(A) * len(B))
# Out:
# A × B = [(1, 'do'), (1, 're'), (2, 'do'), (2, 're'), (3, 'do'), (3, 're')]
# |A| = 3  |B| = 2  |A × B| = 6
# ¿Se cumple |A × B| == |A| · |B|? True

# %% [markdown]
# ### 🧑‍🏫 Yo hago 5.3 — La herramienta estándar y la no conmutatividad
#
# Para productos cartesianos, la biblioteca estándar de Python trae `itertools.product`. La usamos para comprobar que el producto cartesiano **no es conmutativo**: $A \times B \neq B \times A$ (los pares están invertidos).

# %%
from itertools import product   # herramienta estándar para productos cartesianos

BxA = set(product(B, A))
print("B × A =", sorted(BxA))
print("¿A × B == B × A?", AxB == BxA)   # False: el producto cartesiano no es conmutativo
# Out:
# B × A = [('do', 1), ('do', 2), ('do', 3), ('re', 1), ('re', 2), ('re', 3)]
# ¿A × B == B × A? False

# %% [markdown]
# ### 🧑‍🏫 Yo hago 5.4 — Ver el producto cartesiano
#
# Si $A$ y $B$ son conjuntos de números, $A \times B$ forma una **malla de puntos** en el plano: la intuición geométrica del producto cartesiano. Graficamos con `matplotlib`, la biblioteca de visualización más usada en Python (ya viene instalada en Colab).

# %%
import matplotlib.pyplot as plt

A = {1, 2, 3}
B = {1, 2}
AxB = {(a, b) for a in A for b in B}

xs = [par[0] for par in AxB]   # primeras coordenadas
ys = [par[1] for par in AxB]   # segundas coordenadas

plt.figure(figsize=(5, 3.2)) #es el alto y ancho de la figura en pulgadas
plt.scatter(xs, ys, s=40, color="deeppink")
plt.title("A × B con A = {1, 2, 3} y B = {4, 5}")#rotulo principal de la grafica
plt.xlabel("A (primera coordenada)")#rotulo de eje x
plt.ylabel("B (segunda coordenada)")#rotulo de eje y
plt.xticks([1, 2, 3])
plt.yticks([4, 5])
plt.grid(True, linestyle="-") #tipo de linea de la cuadrícula
plt.show()#grafico

# %% [markdown]
# ### ✍️ Tú haces 5.1 — Diseño muestral de una encuesta
#
# Una encuesta nacional estratifica por sexo y región natural:
#
# ```python
# sexo = {"Hombre", "Mujer"}
# region = {"Costa", "Sierra", "Amazonía", "Insular"}
# ```
#
# (a) **Antes de programar**, predice cuántos perfiles muestrales hay usando la regla del producto. (b) Construye por comprensión el conjunto `perfiles` $= \text{sexo} \times \text{region}$. (c) Verifica tu predicción con `len()`.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# sexo = {"Hombre", "Mujer"}
# region = {"Costa", "Sierra", "Amazonía", "Insular"}
#
# perfiles = {(s, r) for s in sexo for r in region}
#
# print("Perfiles muestrales:", sorted(perfiles))
# print("Número de perfiles:", len(perfiles))   # 2 · 4 = 8
# ```
#
# **Comentario:** cada estrato de la encuesta es un elemento de un producto cartesiano. Con tres variables (p. ej., agregando grupo etario) el diseño sería un producto triple $S \times R \times G$, con $|S| \cdot |R| \cdot |G|$ estratos.
#
# </details>

# %%
# ✍️ Escribe aquí tu solución del Tú haces 5.1
sexo = {"Hombre", "Mujer"}
region = {"Costa", "Sierra", "Oriente", "Insular"}
AxB = {(s, r) for s in sexo for r in region}

xs = [par[0] for par in AxB]   # primeras coordenadas
ys = [par[1] for par in AxB]   # segundas coordenadas

plt.figure(figsize=(5, 3.2))  # es el alto y ancho de la figura en pulgadas
plt.scatter(xs, ys, s=40, color="pink")
plt.title("s × r con s = {Hombre, Mujer} y r = {Costa, Sierra, Oriente, Insular}")  # rótulo principal de la gráfica
plt.xlabel("s (primera coordenada)")  # rótulo de eje x
plt.ylabel("r (segunda coordenada)")  # rótulo de eje y
plt.xticks(["Hombre", "Mujer"])
plt.yticks(["Costa", "Sierra", "Oriente", "Insular"])
plt.grid(True, linestyle="--")  # tipo de línea de la cuadrícula
plt.show()  # gráfico
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 14
#      10 plt.scatter(xs, ys, s=40, color="pink")
#      11 plt.title("s × r con s = {Hombre, Mujer} y r = {Costa, Sierra, Oriente, Insular}") #rotulo principal de la grafica
#      12 plt.xlabel("s (primera coordenada)")#rotulo de eje x
#      13 plt.ylabel("r (segunda coordenada)")#rotulo de eje y
# ---> 14 plt.xticks([Hombre, Mujer])
#      15 plt.yticks([Costa, Sierra, Oriente, Insular])
#      16 plt.grid(True, linestyle="--") #tipo de linea de la cuadrícula
#      17 plt.show()#grafico
#
# NameError: name 'Hombre' is not defined

# %% [markdown]
# ### ✍️ Tú haces 5.2 — El cuadrado cartesiano
#
# Sea $A = \{0, 1, 2\}$. (a) Predice la cardinalidad de $A \times A$ (que se escribe $A^2$). (b) Constrúyelo por comprensión y verifica. (c) *Opcional:* adapta el código de la sección 5.4 para graficarlo.
#
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# A = {0, 1, 2}
# AxA = {(a, b) for a in A for b in A}
#
# print("A × A =", sorted(AxA))
# print("|A × A| =", len(AxA))   # 3 · 3 = 9
#
# # (c) Opcional: graficar la malla 3 × 3
# import matplotlib.pyplot as plt
#
# xs = [par[0] for par in AxA]
# ys = [par[1] for par in AxA]
#
# plt.figure(figsize=(4, 4))
# plt.scatter(xs, ys, s=90, color="darkred")
# plt.title("A × A con A = {0, 1, 2}")
# plt.xticks([0, 1, 2])
# plt.yticks([0, 1, 2])
# plt.grid(True, linestyle=":")
# plt.show()
# ```
#
# **Comentario:** $A^2$ es una malla cuadrada de $9$ puntos. Llevando la idea al límite, $\mathbb{R}^2$ es el plano completo: cada punto del plano cartesiano *es* un par ordenado.
#
# </details>

# %%
# ✍️ Escribe aquí tu solución del Tú haces 5.2
A = {0, 1, 2 }

# %% [markdown]
# ## 6. Síntesis y para llevar
#
# **Diccionario matemáticas ↔ Python de esta clase:**
#
# | Matemáticas | Python |
# |---|---|
# | $A = \{1, 2, 3\}$ | `A = {1, 2, 3}` |
# | $x \in A$ · $x \notin A$ | `x in A` · `x not in A` |
# | $\lvert A \rvert$ | `len(A)` |
# | $\emptyset$ | `set()` |
# | $A \cup B$ · $A \cap B$ | `A \| B` · `A & B` |
# | $A \setminus B$ · $A \triangle B$ | `A - B` · `A ^ B` |
# | $A \subseteq B$ · $A \subset B$ | `A <= B` · `A < B` |
# | par ordenado $(a, b)$ | tupla `(a, b)` |
# | $A \times B = \{(a,b) : a \in A,\, b \in B\}$ | `{(a, b) for a in A for b in B}` |
# | $R = \{(a,b) \in A \times B : \text{condición}\}$ | `{(a, b) for a in A for b in B if condicion}` |
#
# **Hoy aprendiste a:** ejecutar y crear celdas en Colab · usar variables y `print()` · definir conjuntos y comprobar que eliminan duplicados y no tienen orden · operar con $\cup, \cap, \setminus, \triangle, \subseteq$ · construir productos cartesianos por comprensión y con `itertools.product` · verificar la regla del producto · graficar una malla con `matplotlib` · escribir tu primera relación.
#
# **Próxima clase:** relaciones y funciones — dominio, rango, y funciones como relaciones especiales.
#
# **Para profundizar:**
# - Tutorial oficial de Python en español, sección de conjuntos: https://docs.python.org/es/3/tutorial/datastructures.html#sets
# - Cuaderno de bienvenida de Google Colab: https://colab.research.google.com/notebooks/intro.ipynb
#
# > ✅ **Antes de cerrar:** verifica que guardaste tu copia (`Archivo → Guardar una copia en Drive`) con tus soluciones de los *Tú haces*.
